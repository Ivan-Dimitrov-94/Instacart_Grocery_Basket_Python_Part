# %% [markdown]
# # 4.8 - Grouping Data & Aggregating Variables

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Creating a path:
path = r'D:\Nov Laptop\Ivan Dimitrov - Data Analyst (CF)\13-06-2023 Instacart Basket Analysis'

# %% [markdown]
# #### Step 1: Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
# Loading the file after the path
df_ords_prods_last_updated = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data','orders_products_merged_4.7_updated.pkl'))

# %%
# Importing the department file for reference
df_dept = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'))

# %%
df_dept
# Out:
#     Unnamed: 0       department
# 0            1           frozen
# 1            2            other
# 2            3           bakery
# 3            4          produce
# 4            5          alcohol
# 5            6    international
# 6            7        beverages
# 7            8             pets
# 8            9  dry goods pasta
# 9           10             bulk
# 10          11    personal care
# 11          12     meat seafood
# 12          13           pantry
# 13          14        breakfast
# 14          15     canned goods
# 15          16       dairy eggs
# 16          17        household
# 17          18           babies
# 18          19           snacks
# 19          20             deli
# 20          21          missing

# %% [markdown]
# #### Step 2: In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Step 1: Check the file's dimensions
df_ords_prods_last_updated.shape
# Out:
# (32404859, 18)

# %%
# Step 2: Group by "product_name" 
df_ords_prods_last_updated.groupby('product_name')

# %%
# Step 3: Split the data into groups by "department_id" and then calculate the mean for the "order_number" column
df_ords_prods_last_updated.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Step 3: Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# #### As we can see the results are quite different.
# #### Subset orders minimal avg is (11.294069 - for dep 17 "household") - while for the Whole data set it's (15.215751 - for dep 5 "Alcohol")
# #### Subset orders maximal avg is (19.463012 - for dep 16 "dairy eggs") - while for the Whole data set it's (22.902379 - for dep 21 "missing")

# %% [markdown]
# ### Step 4: Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Step 1 of creating a loyalty flag is to create a "max_order" column
# to pile the aggregated results from grouping "user_id" and "order_number"
df_ords_prods_last_updated['max_order'] = df_ords_prods_last_updated.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Bypassing the limit of rows that can be shown
pd.options.display.max_rows = None

# %%
df_ords_prods_last_updated.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
# 60   2728456       82             4                   0                 11
# 61   2653743       82             6                   4                  9
# 62   1358880       82             9                   1                 10
# 63    343588       82            10                   2                 11
# 64   3034663       82            15                   2                 11
# 65    147262       82            18                   1                 13
# 66   3144004       82            19                   2                 15
# 67   2126069       98             3                   0                  9
# 68   2210120       98             7                   5                 14
# 69    681011       98             9                   3                  9
# 70   2846344       98            11                   4                 13
# 71    747431       98            12                   6                 13
# 72   2383054       98            13                   4                 11
# 73   1993729       98            14                   5                  8
# 74   1403849      109             3                   3                 17
# 75    520620      120             1                   3                 11
# 76   3273029      120             3                   2                  8
# 77   1861943      185             2                   1                 12
# 78   2040988      195             1                   1                 14
# 79   1680569      195             8                   1                  9
# 80    276171      195            19                   5                 11
# 81   2744976      195            22                   5                 10
# 82   2781919      195            25                   1                 14
# 83   1738718      195            31                   2                  8
# 84   3058369      195            34                   3                 10
# 85   1485596      195            37                   2                 15
# 86    417035      195            40                   3                 16
# 87   1615297      195            47                   5                 10
# 88   1765587      195            52                   3                 12
# 89    745908      195            57                   4                 11
# 90   2505656      222            17                   2                 12
# 91   3268370      222            38                   5                 15
# 92   2016711      290             9                   5                 19
# 93   2706088      290            28                   6                 10
# 94   1952286      331             6                   5                 16
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
# 20                     8.0         196                 14          1
# 21                     4.0         196                  9          0
# 22                     3.0         196                  1          1
# 23                     NaN         196                  4          0
# 24                     7.0         196                  5          1
# 25                     7.0         196                  3          1
# 26                     8.0         196                  6          1
# 27                     8.0         196                  5          1
# 28                     7.0         196                  5          1
# 29                     8.0         196                  4          1
# 30                     7.0         196                  3          1
# 31                     6.0         196                  7          1
# 32                     8.0         196                  3          1
# 33                     6.0         196                  4          1
# 34                    14.0         196                  6          1
# 35                     8.0         196                  4          1
# 36                    30.0         196                  1          1
# 37                     NaN         196                  1          0
# 38                     5.0         196                  2          1
# 39                     7.0         196                  2          1
# 40                     8.0         196                  1          1
# 41                     8.0         196                  2          1
# 42                     7.0         196                  2          1
# 43                     7.0         196                  1          1
# 44                     7.0         196                  1          1
# 45                     6.0         196                  1          1
# 46                     7.0         196                  1          1
# 47                     8.0         196                  1          1
# 48                     6.0         196                  1          1
# 49                     7.0         196                  1          1
# 50                     9.0         196                  1          1
# 51                     4.0         196                  1          1
# 52                     9.0         196                  2          1
# 53                     5.0         196                  2          1
# 54                    14.0         196                  3          1
# 55                    14.0         196                  1          1
# 56                    14.0         196                  2          0
# 57                    30.0         196                  1          1
# 58                     NaN         196                  6          0
# 59                     5.0         196                  2          1
# 60                    16.0         196                  1          1
# 61                    13.0         196                  5          1
# 62                    30.0         196                  1          1
# 63                     1.0         196                  1          1
# 64                    12.0         196                  1          1
# 65                     7.0         196                  1          1
# 66                     8.0         196                  1          1
# 67                    25.0         196                  7          0
# 68                     5.0         196                  1          1
# 69                    30.0         196                  1          1
# 70                    15.0         196                  2          1
# 71                    30.0         196                  4          1
# 72                    30.0         196                  1          1
# 73                     8.0         196                  2          1
# 74                     9.0         196                  5          0
# 75                     NaN         196                  2          0
# 76                    19.0         196                  2          1
# 77                    25.0         196                 10          0
# 78                     NaN         196                  2          0
# 79                     4.0         196                  2          1
# 80                     3.0         196                  2          1
# 81                     7.0         196                  2          1
# 82                     4.0         196                  1          1
# 83                     4.0         196                  2          1
# 84                     6.0         196                  2          1
# 85                     0.0         196                  2          1
# 86                     2.0         196                  2          1
# 87                     2.0         196                  2          1
# 88                     2.0         196                  3          1
# 89                     3.0         196                  3          1
# 90                     1.0         196                  2          0
# 91                     1.0         196                  6          1
# 92                     6.0         196                  8          0
# 93                     7.0         196                 16          1
# 94                    30.0         196                  8          0
# 95                     NaN         196                  1          0
# 96                     3.0         196                  9          0
# 97                    22.0         196                  3          0
# 98                    30.0         196                  2          0
# 99                    16.0         196                  2          1
#
#    product_name  aisle_id  department_id  prices _merge        price_label  \
# 0          Soda        77              7     9.0   both  Mid-range product
# 1          Soda        77              7     9.0   both  Mid-range product
# 2          Soda        77              7     9.0   both  Mid-range product
# 3          Soda        77              7     9.0   both  Mid-range product
# 4          Soda        77              7     9.0   both  Mid-range product
# 5          Soda        77              7     9.0   both  Mid-range product
# 6          Soda        77              7     9.0   both  Mid-range product
# 7          Soda        77              7     9.0   both  Mid-range product
# 8          Soda        77              7     9.0   both  Mid-range product
# 9          Soda        77              7     9.0   both  Mid-range product
# 10         Soda        77              7     9.0   both  Mid-range product
# 11         Soda        77              7     9.0   both  Mid-range product
# 12         Soda        77              7     9.0   both  Mid-range product
# 13         Soda        77              7     9.0   both  Mid-range product
# 14         Soda        77              7     9.0   both  Mid-range product
# 15         Soda        77              7     9.0   both  Mid-range product
# 16         Soda        77              7     9.0   both  Mid-range product
# 17         Soda        77              7     9.0   both  Mid-range product
# 18         Soda        77              7     9.0   both  Mid-range product
# 19         Soda        77              7     9.0   both  Mid-range product
# 20         Soda        77              7     9.0   both  Mid-range product
# 21         Soda        77              7     9.0   both  Mid-range product
# 22         Soda        77              7     9.0   both  Mid-range product
# 23         Soda        77              7     9.0   both  Mid-range product
# 24         Soda        77              7     9.0   both  Mid-range product
# 25         Soda        77              7     9.0   both  Mid-range product
# 26         Soda        77              7     9.0   both  Mid-range product
# 27         Soda        77              7     9.0   both  Mid-range product
# 28         Soda        77              7     9.0   both  Mid-range product
# 29         Soda        77              7     9.0   both  Mid-range product
# 30         Soda        77              7     9.0   both  Mid-range product
# 31         Soda        77              7     9.0   both  Mid-range product
# 32         Soda        77              7     9.0   both  Mid-range product
# 33         Soda        77              7     9.0   both  Mid-range product
# 34         Soda        77              7     9.0   both  Mid-range product
# 35         Soda        77              7     9.0   both  Mid-range product
# 36         Soda        77              7     9.0   both  Mid-range product
# 37         Soda        77              7     9.0   both  Mid-range product
# 38         Soda        77              7     9.0   both  Mid-range product
# 39         Soda        77              7     9.0   both  Mid-range product
# 40         Soda        77              7     9.0   both  Mid-range product
# 41         Soda        77              7     9.0   both  Mid-range product
# 42         Soda        77              7     9.0   both  Mid-range product
# 43         Soda        77              7     9.0   both  Mid-range product
# 44         Soda        77              7     9.0   both  Mid-range product
# 45         Soda        77              7     9.0   both  Mid-range product
# 46         Soda        77              7     9.0   both  Mid-range product
# 47         Soda        77              7     9.0   both  Mid-range product
# 48         Soda        77              7     9.0   both  Mid-range product
# 49         Soda        77              7     9.0   both  Mid-range product
# 50         Soda        77              7     9.0   both  Mid-range product
# 51         Soda        77              7     9.0   both  Mid-range product
# 52         Soda        77              7     9.0   both  Mid-range product
# 53         Soda        77              7     9.0   both  Mid-range product
# 54         Soda        77              7     9.0   both  Mid-range product
# 55         Soda        77              7     9.0   both  Mid-range product
# 56         Soda        77              7     9.0   both  Mid-range product
# 57         Soda        77              7     9.0   both  Mid-range product
# 58         Soda        77              7     9.0   both  Mid-range product
# 59         Soda        77              7     9.0   both  Mid-range product
# 60         Soda        77              7     9.0   both  Mid-range product
# 61         Soda        77              7     9.0   both  Mid-range product
# 62         Soda        77              7     9.0   both  Mid-range product
# 63         Soda        77              7     9.0   both  Mid-range product
# 64         Soda        77              7     9.0   both  Mid-range product
# 65         Soda        77              7     9.0   both  Mid-range product
# 66         Soda        77              7     9.0   both  Mid-range product
# 67         Soda        77              7     9.0   both  Mid-range product
# 68         Soda        77              7     9.0   both  Mid-range product
# 69         Soda        77              7     9.0   both  Mid-range product
# 70         Soda        77              7     9.0   both  Mid-range product
# 71         Soda        77              7     9.0   both  Mid-range product
# 72         Soda        77              7     9.0   both  Mid-range product
# 73         Soda        77              7     9.0   both  Mid-range product
# 74         Soda        77              7     9.0   both  Mid-range product
# 75         Soda        77              7     9.0   both  Mid-range product
# 76         Soda        77              7     9.0   both  Mid-range product
# 77         Soda        77              7     9.0   both  Mid-range product
# 78         Soda        77              7     9.0   both  Mid-range product
# 98  Regularly busy    Busiest days        Average Orders         22
# 99  Regularly busy    Slowest days        Average Orders         22

# %%
# Fixing the whole issue with "NaN" results:
df_ords_prods_last_updated['prices'].mean()
# Out:
# nan

# %%
df_ords_prods_last_updated['prices'] = df_ords_prods_last_updated['prices'].astype('float64')

# %%
df_ords_prods_last_updated['prices'].mean()
# Out:
# inf

# %%
inf_count = (df_ords_prods_last_updated['prices'] == float('inf')).sum()

# %%
inf_count
# Out:
# 698

# %%
df_ords_prods_last_updated = df_ords_prods_last_updated[~(df_ords_prods_last_updated['prices'] == float('inf'))]

# %%
df_ords_prods_last_updated.reset_index(drop=True, inplace=True)

# %%
df_ords_prods_last_updated['prices'].mean()
# Out:
# 9.825785349058837

# %%
# Create flags to assign "loyalty" labels to user ID based on max order value
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\ivand\AppData\Local\Temp\ipykernel_15828\1618057219.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_last_updated.loc[df_ords_prods_last_updated['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_last_updated.loc[(df_ords_prods_last_updated['max_order'] <= 40) & (df_ords_prods_last_updated['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check frequencies of loyalty flags for accuracy
df_ords_prods_last_updated['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876363
# Loyal customer      10284010
# New customer         6243788
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### Step 5: The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# To do so we create a group by "prices" 
df_ords_prods_last_updated.groupby('prices')

# %%
# Then we split the data into groups by "loyalty_flag" and then calculate the mean for each "prices" column
df_ords_prods_last_updated.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer     9.578717
# New customer      10.059199
# Regular customer   9.894029

# %% [markdown]
# ### Step 6: The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:

# %% [markdown]
# #### Subestep: If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.” If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# First we need to group our data by "user_id", generate average product price for each user,
# and create "avg_price" column for the aggregated results
df_ords_prods_last_updated['avg_price'] = df_ords_prods_last_updated.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\ivand\AppData\Local\Temp\ipykernel_15828\2960293675.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_last_updated['avg_price'] = df_ords_prods_last_updated.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check grouping
df_ords_prods_last_updated.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
# 60   2728456       82             4                   0                 11
# 61   2653743       82             6                   4                  9
# 62   1358880       82             9                   1                 10
# 63    343588       82            10                   2                 11
# 64   3034663       82            15                   2                 11
# 65    147262       82            18                   1                 13
# 66   3144004       82            19                   2                 15
# 67   2126069       98             3                   0                  9
# 68   2210120       98             7                   5                 14
# 69    681011       98             9                   3                  9
# 70   2846344       98            11                   4                 13
# 71    747431       98            12                   6                 13
# 72   2383054       98            13                   4                 11
# 73   1993729       98            14                   5                  8
# 74   1403849      109             3                   3                 17
# 75    520620      120             1                   3                 11
# 76   3273029      120             3                   2                  8
# 77   1861943      185             2                   1                 12
# 78   2040988      195             1                   1                 14
# 79   1680569      195             8                   1                  9
# 80    276171      195            19                   5                 11
# 81   2744976      195            22                   5                 10
# 82   2781919      195            25                   1                 14
# 83   1738718      195            31                   2                  8
# 84   3058369      195            34                   3                 10
# 85   1485596      195            37                   2                 15
# 86    417035      195            40                   3                 16
# 87   1615297      195            47                   5                 10
# 88   1765587      195            52                   3                 12
# 89    745908      195            57                   4                 11
# 90   2505656      222            17                   2                 12
# 91   3268370      222            38                   5                 15
# 92   2016711      290             9                   5                 19
# 93   2706088      290            28                   6                 10
# 94   1952286      331             6                   5                 16
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
# 20                     8.0         196                 14          1
# 21                     4.0         196                  9          0
# 22                     3.0         196                  1          1
# 23                     NaN         196                  4          0
# 24                     7.0         196                  5          1
# 25                     7.0         196                  3          1
# 26                     8.0         196                  6          1
# 27                     8.0         196                  5          1
# 28                     7.0         196                  5          1
# 29                     8.0         196                  4          1
# 30                     7.0         196                  3          1
# 31                     6.0         196                  7          1
# 32                     8.0         196                  3          1
# 33                     6.0         196                  4          1
# 34                    14.0         196                  6          1
# 35                     8.0         196                  4          1
# 36                    30.0         196                  1          1
# 37                     NaN         196                  1          0
# 38                     5.0         196                  2          1
# 39                     7.0         196                  2          1
# 40                     8.0         196                  1          1
# 41                     8.0         196                  2          1
# 42                     7.0         196                  2          1
# 43                     7.0         196                  1          1
# 44                     7.0         196                  1          1
# 45                     6.0         196                  1          1
# 46                     7.0         196                  1          1
# 47                     8.0         196                  1          1
# 48                     6.0         196                  1          1
# 49                     7.0         196                  1          1
# 50                     9.0         196                  1          1
# 51                     4.0         196                  1          1
# 52                     9.0         196                  2          1
# 53                     5.0         196                  2          1
# 54                    14.0         196                  3          1
# 55                    14.0         196                  1          1
# 56                    14.0         196                  2          0
# 57                    30.0         196                  1          1
# 58                     NaN         196                  6          0
# 59                     5.0         196                  2          1
# 60                    16.0         196                  1          1
# 61                    13.0         196                  5          1
# 62                    30.0         196                  1          1
# 63                     1.0         196                  1          1
# 64                    12.0         196                  1          1
# 65                     7.0         196                  1          1
# 66                     8.0         196                  1          1
# 67                    25.0         196                  7          0
# 68                     5.0         196                  1          1
# 69                    30.0         196                  1          1
# 70                    15.0         196                  2          1
# 71                    30.0         196                  4          1
# 72                    30.0         196                  1          1
# 73                     8.0         196                  2          1
# 74                     9.0         196                  5          0
# 75                     NaN         196                  2          0
# 76                    19.0         196                  2          1
# 77                    25.0         196                 10          0
# 78                     NaN         196                  2          0
# 79                     4.0         196                  2          1
# 80                     3.0         196                  2          1
# 81                     7.0         196                  2          1
# 82                     4.0         196                  1          1
# 83                     4.0         196                  2          1
# 84                     6.0         196                  2          1
# 85                     0.0         196                  2          1
# 86                     2.0         196                  2          1
# 87                     2.0         196                  2          1
# 88                     2.0         196                  3          1
# 89                     3.0         196                  3          1
# 90                     1.0         196                  2          0
# 91                     1.0         196                  6          1
# 92                     6.0         196                  8          0
# 93                     7.0         196                 16          1
# 94                    30.0         196                  8          0
# 95                     NaN         196                  1          0
# 96                     3.0         196                  9          0
# 97                    22.0         196                  3          0
# 98                    30.0         196                  2          0
# 99                    16.0         196                  2          1
#
#    product_name  ...  department_id  prices  _merge        price_label  \
# 0          Soda  ...              7     9.0    both  Mid-range product
# 1          Soda  ...              7     9.0    both  Mid-range product
# 2          Soda  ...              7     9.0    both  Mid-range product
# 3          Soda  ...              7     9.0    both  Mid-range product
# 4          Soda  ...              7     9.0    both  Mid-range product
# 5          Soda  ...              7     9.0    both  Mid-range product
# 6          Soda  ...              7     9.0    both  Mid-range product
# 7          Soda  ...              7     9.0    both  Mid-range product
# 8          Soda  ...              7     9.0    both  Mid-range product
# 9          Soda  ...              7     9.0    both  Mid-range product
# 10         Soda  ...              7     9.0    both  Mid-range product
# 11         Soda  ...              7     9.0    both  Mid-range product
# 12         Soda  ...              7     9.0    both  Mid-range product
# 13         Soda  ...              7     9.0    both  Mid-range product
# 14         Soda  ...              7     9.0    both  Mid-range product
# 15         Soda  ...              7     9.0    both  Mid-range product
# 16         Soda  ...              7     9.0    both  Mid-range product
# 17         Soda  ...              7     9.0    both  Mid-range product
# 18         Soda  ...              7     9.0    both  Mid-range product
# 19         Soda  ...              7     9.0    both  Mid-range product
# 20         Soda  ...              7     9.0    both  Mid-range product
# 21         Soda  ...              7     9.0    both  Mid-range product
# 22         Soda  ...              7     9.0    both  Mid-range product
# 23         Soda  ...              7     9.0    both  Mid-range product
# 24         Soda  ...              7     9.0    both  Mid-range product
# 25         Soda  ...              7     9.0    both  Mid-range product
# 26         Soda  ...              7     9.0    both  Mid-range product
# 27         Soda  ...              7     9.0    both  Mid-range product
# 28         Soda  ...              7     9.0    both  Mid-range product
# 29         Soda  ...              7     9.0    both  Mid-range product
# 30         Soda  ...              7     9.0    both  Mid-range product
# 31         Soda  ...              7     9.0    both  Mid-range product
# 32         Soda  ...              7     9.0    both  Mid-range product
# 33         Soda  ...              7     9.0    both  Mid-range product
# 34         Soda  ...              7     9.0    both  Mid-range product
# 35         Soda  ...              7     9.0    both  Mid-range product
# 36         Soda  ...              7     9.0    both  Mid-range product
# 37         Soda  ...              7     9.0    both  Mid-range product
# 38         Soda  ...              7     9.0    both  Mid-range product
# 39         Soda  ...              7     9.0    both  Mid-range product
# 40         Soda  ...              7     9.0    both  Mid-range product
# 41         Soda  ...              7     9.0    both  Mid-range product
# 42         Soda  ...              7     9.0    both  Mid-range product
# 43         Soda  ...              7     9.0    both  Mid-range product
# 44         Soda  ...              7     9.0    both  Mid-range product
# 45         Soda  ...              7     9.0    both  Mid-range product
# 46         Soda  ...              7     9.0    both  Mid-range product
# 47         Soda  ...              7     9.0    both  Mid-range product
# 48         Soda  ...              7     9.0    both  Mid-range product
# 49         Soda  ...              7     9.0    both  Mid-range product
# 50         Soda  ...              7     9.0    both  Mid-range product
# 51         Soda  ...              7     9.0    both  Mid-range product
# 52         Soda  ...              7     9.0    both  Mid-range product
# 53         Soda  ...              7     9.0    both  Mid-range product
# 54         Soda  ...              7     9.0    both  Mid-range product
# 55         Soda  ...              7     9.0    both  Mid-range product
# 56         Soda  ...              7     9.0    both  Mid-range product
# 57         Soda  ...              7     9.0    both  Mid-range product
# 58         Soda  ...              7     9.0    both  Mid-range product
# 59         Soda  ...              7     9.0    both  Mid-range product
# 60         Soda  ...              7     9.0    both  Mid-range product
# 61         Soda  ...              7     9.0    both  Mid-range product
# 62         Soda  ...              7     9.0    both  Mid-range product
# 63         Soda  ...              7     9.0    both  Mid-range product
# 64         Soda  ...              7     9.0    both  Mid-range product
# 65         Soda  ...              7     9.0    both  Mid-range product
# 66         Soda  ...              7     9.0    both  Mid-range product
# 67         Soda  ...              7     9.0    both  Mid-range product
# 68         Soda  ...              7     9.0    both  Mid-range product
# 69         Soda  ...              7     9.0    both  Mid-range product
# 70         Soda  ...              7     9.0    both  Mid-range product
# 71         Soda  ...              7     9.0    both  Mid-range product
# 72         Soda  ...              7     9.0    both  Mid-range product
# 73         Soda  ...              7     9.0    both  Mid-range product
# 74         Soda  ...              7     9.0    both  Mid-range product
# 75         Soda  ...              7     9.0    both  Mid-range product
# 76         Soda  ...              7     9.0    both  Mid-range product
# 77         Soda  ...              7     9.0    both  Mid-range product
# 78         Soda  ...              7     9.0    both  Mid-range product
# 79         Soda  ...              7     9.0    both  Mid-range product
# 80         Soda  ...              7     9.0    both  Mid-range product
# 81         Soda  ...              7     9.0    both  Mid-range product
# 82         Soda  ...              7     9.0    both  Mid-range product
# 83         Soda  ...              7     9.0    both  Mid-range product
# 84         Soda  ...              7     9.0    both  Mid-range product
# 85         Soda  ...              7     9.0    both  Mid-range product
# 86         Soda  ...              7     9.0    both  Mid-range product
# 87         Soda  ...              7     9.0    both  Mid-range product
# 88         Soda  ...              7     9.0    both  Mid-range product
# 89         Soda  ...              7     9.0    both  Mid-range product
# 90         Soda  ...              7     9.0    both  Mid-range product
# 91         Soda  ...              7     9.0    both  Mid-range product
# 92         Soda  ...              7     9.0    both  Mid-range product
# 93         Soda  ...              7     9.0    both  Mid-range product
# 94         Soda  ...              7     9.0    both  Mid-range product
# 95         Soda  ...              7     9.0    both  Mid-range product
# 96         Soda  ...              7     9.0    both  Mid-range product
# 97         Soda  ...              7     9.0    both  Mid-range product
# 98         Soda  ...              7     9.0    both  Mid-range product
# 99         Soda  ...              7     9.0    both  Mid-range product
#
#        busiest_day    Busiest_Days busiest_period_of_day max_order  \
# 0   Regularly busy  Regularly busy        Average Orders        10
# 1   Regularly busy    Slowest days        Average Orders        10
# 2   Regularly busy    Slowest days           Most Orders        10
# 3       Least busy    Slowest days        Average Orders        10
# 4       Least busy    Slowest days           Most Orders        10
# 5   Regularly busy  Regularly busy        Average Orders        10
# 6   Regularly busy    Busiest days           Most Orders        10
# 7   Regularly busy    Busiest days           Most Orders        10
# 8   Regularly busy    Busiest days           Most Orders        10
# 9       Least busy    Slowest days        Average Orders        10
# 10  Regularly busy    Busiest days           Most Orders        22
# 11  Regularly busy  Regularly busy           Most Orders        22
# 12  Regularly busy  Regularly busy           Most Orders        22
# 13  Regularly busy    Busiest days           Most Orders        22
# 14  Regularly busy    Busiest days           Most Orders        22
# 15  Regularly busy  Regularly busy           Most Orders         9
# 16  Regularly busy  Regularly busy           Most Orders         9
# 17      Least busy    Slowest days        Average Orders         9
# 18  Regularly busy    Slowest days           Most Orders        33
# 19  Regularly busy    Slowest days        Average Orders        20
# 20  Regularly busy    Slowest days           Most Orders        20
# 21      Least busy    Slowest days           Most Orders        11
# 22      Least busy    Slowest days           Most Orders        11
# 23  Regularly busy    Busiest days           Most Orders        27
# 24  Regularly busy    Busiest days           Most Orders        27
# 25  Regularly busy    Busiest days           Most Orders        27
# 26  Regularly busy  Regularly busy           Most Orders        27
# 27  Regularly busy  Regularly busy        Average Orders        27
# 28  Regularly busy    Busiest days           Most Orders        27
# 29  Regularly busy  Regularly busy           Most Orders        27
# 86    Loyal customer   7.149842
# 87    Loyal customer   7.149842
# 88    Loyal customer   7.149842
# 89    Loyal customer   7.149842
# 90    Loyal customer   6.862379
# 91    Loyal customer   6.862379
# 92    Loyal customer   7.285560
# 93    Loyal customer   7.285560
# 94      New customer   7.704577
# 95      New customer  10.006287
# 96      New customer   8.496262
# 97      New customer   7.396153
# 98  Regular customer   7.387799
# 99  Regular customer   7.387799
#
# [100 rows x 21 columns]

# %%
# Create flags to assign "spending" labels to user ID based on average product price
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['avg_price'] < 10, 'spending_flag'] = 'Low spender'
# Out:
# C:\Users\ivand\AppData\Local\Temp\ipykernel_15828\555147400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_last_updated.loc[df_ords_prods_last_updated['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check frequencies of spending flags for accuracy
df_ords_prods_last_updated['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31827629
# High spender      576532
# Name: spending_flag, dtype: int64

# %% [markdown]
# ### Step 7: In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# #### If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# #### If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# #### If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# To do so we need to group data by "user_id" column,
# generate median product of "days since prior order" column,
# and create "median_days" for aggregation results
df_ords_prods_last_updated['median_days'] = df_ords_prods_last_updated.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\ivand\AppData\Local\Temp\ipykernel_15828\715173083.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_last_updated['median_days'] = df_ords_prods_last_updated.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Check grouping
df_ords_prods_last_updated.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#   product_name  ...  _merge        price_label     busiest_day  \
# 0         Soda  ...    both  Mid-range product  Regularly busy
# 1         Soda  ...    both  Mid-range product  Regularly busy
# 2         Soda  ...    both  Mid-range product  Regularly busy
# 3         Soda  ...    both  Mid-range product      Least busy
# 4         Soda  ...    both  Mid-range product      Least busy
# 5         Soda  ...    both  Mid-range product  Regularly busy
# 6         Soda  ...    both  Mid-range product  Regularly busy
# 7         Soda  ...    both  Mid-range product  Regularly busy
# 8         Soda  ...    both  Mid-range product  Regularly busy
# 9         Soda  ...    both  Mid-range product      Least busy
#
#      Busiest_Days busiest_period_of_day max_order  loyalty_flag avg_price  \
# 0  Regularly busy        Average Orders        10  New customer  6.367535
# 1    Slowest days        Average Orders        10  New customer  6.367535
# 2    Slowest days           Most Orders        10  New customer  6.367535
# 3    Slowest days        Average Orders        10  New customer  6.367535
# 4    Slowest days           Most Orders        10  New customer  6.367535
# 5  Regularly busy        Average Orders        10  New customer  6.367535
# 6    Busiest days           Most Orders        10  New customer  6.367535
# 7    Busiest days           Most Orders        10  New customer  6.367535
# 8    Busiest days           Most Orders        10  New customer  6.367535
# 9    Slowest days        Average Orders        10  New customer  6.367535
#
#    spending_flag median_days
# 0    Low spender        20.5
# 1    Low spender        20.5
# 2    Low spender        20.5
# 3    Low spender        20.5
# 4    Low spender        20.5
# 5    Low spender        20.5
# 6    Low spender        20.5
# 7    Low spender        20.5
# 8    Low spender        20.5
# 9    Low spender        20.5
#
# [10 rows x 23 columns]

# %%
# Then we need to create flags and assign "freqency" labels to "user ID" based on the "median_days" since last order
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\ivand\AppData\Local\Temp\ipykernel_15828\1580902318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_prods_last_updated.loc[df_ords_prods_last_updated['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_last_updated.loc[(df_ords_prods_last_updated['median_days'] > 10) & (df_ords_prods_last_updated['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check frequencies of spending flags for accuracy
df_ords_prods_last_updated['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21559380
# Regular customer          7208433
# Non-frequent customer     3636343
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_last_updated.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
# 60   2728456       82             4                   0                 11
# 61   2653743       82             6                   4                  9
# 62   1358880       82             9                   1                 10
# 63    343588       82            10                   2                 11
# 64   3034663       82            15                   2                 11
# 65    147262       82            18                   1                 13
# 66   3144004       82            19                   2                 15
# 67   2126069       98             3                   0                  9
# 68   2210120       98             7                   5                 14
# 69    681011       98             9                   3                  9
# 70   2846344       98            11                   4                 13
# 71    747431       98            12                   6                 13
# 72   2383054       98            13                   4                 11
# 73   1993729       98            14                   5                  8
# 74   1403849      109             3                   3                 17
# 75    520620      120             1                   3                 11
# 76   3273029      120             3                   2                  8
# 77   1861943      185             2                   1                 12
# 78   2040988      195             1                   1                 14
# 79   1680569      195             8                   1                  9
# 80    276171      195            19                   5                 11
# 81   2744976      195            22                   5                 10
# 82   2781919      195            25                   1                 14
# 83   1738718      195            31                   2                  8
# 84   3058369      195            34                   3                 10
# 85   1485596      195            37                   2                 15
# 86    417035      195            40                   3                 16
# 87   1615297      195            47                   5                 10
# 88   1765587      195            52                   3                 12
# 89    745908      195            57                   4                 11
# 90   2505656      222            17                   2                 12
# 91   3268370      222            38                   5                 15
# 92   2016711      290             9                   5                 19
# 93   2706088      290            28                   6                 10
# 94   1952286      331             6                   5                 16
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
# 20                     8.0         196                 14          1
# 21                     4.0         196                  9          0
# 22                     3.0         196                  1          1
# 23                     NaN         196                  4          0
# 24                     7.0         196                  5          1
# 25                     7.0         196                  3          1
# 26                     8.0         196                  6          1
# 27                     8.0         196                  5          1
# 28                     7.0         196                  5          1
# 29                     8.0         196                  4          1
# 30                     7.0         196                  3          1
# 31                     6.0         196                  7          1
# 32                     8.0         196                  3          1
# 33                     6.0         196                  4          1
# 34                    14.0         196                  6          1
# 35                     8.0         196                  4          1
# 36                    30.0         196                  1          1
# 37                     NaN         196                  1          0
# 38                     5.0         196                  2          1
# 39                     7.0         196                  2          1
# 40                     8.0         196                  1          1
# 41                     8.0         196                  2          1
# 42                     7.0         196                  2          1
# 43                     7.0         196                  1          1
# 44                     7.0         196                  1          1
# 45                     6.0         196                  1          1
# 46                     7.0         196                  1          1
# 47                     8.0         196                  1          1
# 48                     6.0         196                  1          1
# 49                     7.0         196                  1          1
# 50                     9.0         196                  1          1
# 51                     4.0         196                  1          1
# 52                     9.0         196                  2          1
# 53                     5.0         196                  2          1
# 54                    14.0         196                  3          1
# 55                    14.0         196                  1          1
# 56                    14.0         196                  2          0
# 57                    30.0         196                  1          1
# 58                     NaN         196                  6          0
# 59                     5.0         196                  2          1
# 60                    16.0         196                  1          1
# 61                    13.0         196                  5          1
# 62                    30.0         196                  1          1
# 63                     1.0         196                  1          1
# 64                    12.0         196                  1          1
# 65                     7.0         196                  1          1
# 66                     8.0         196                  1          1
# 67                    25.0         196                  7          0
# 68                     5.0         196                  1          1
# 69                    30.0         196                  1          1
# 70                    15.0         196                  2          1
# 71                    30.0         196                  4          1
# 72                    30.0         196                  1          1
# 73                     8.0         196                  2          1
# 74                     9.0         196                  5          0
# 75                     NaN         196                  2          0
# 76                    19.0         196                  2          1
# 77                    25.0         196                 10          0
# 78                     NaN         196                  2          0
# 79                     4.0         196                  2          1
# 80                     3.0         196                  2          1
# 81                     7.0         196                  2          1
# 82                     4.0         196                  1          1
# 83                     4.0         196                  2          1
# 84                     6.0         196                  2          1
# 85                     0.0         196                  2          1
# 86                     2.0         196                  2          1
# 87                     2.0         196                  2          1
# 88                     2.0         196                  3          1
# 89                     3.0         196                  3          1
# 90                     1.0         196                  2          0
# 91                     1.0         196                  6          1
# 92                     6.0         196                  8          0
# 93                     7.0         196                 16          1
# 94                    30.0         196                  8          0
# 95                     NaN         196                  1          0
# 96                     3.0         196                  9          0
# 97                    22.0         196                  3          0
# 98                    30.0         196                  2          0
# 99                    16.0         196                  2          1
#
#    product_name  ...        price_label     busiest_day    Busiest_Days  \
# 0          Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 1          Soda  ...  Mid-range product  Regularly busy    Slowest days
# 2          Soda  ...  Mid-range product  Regularly busy    Slowest days
# 3          Soda  ...  Mid-range product      Least busy    Slowest days
# 4          Soda  ...  Mid-range product      Least busy    Slowest days
# 5          Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 6          Soda  ...  Mid-range product  Regularly busy    Busiest days
# 7          Soda  ...  Mid-range product  Regularly busy    Busiest days
# 8          Soda  ...  Mid-range product  Regularly busy    Busiest days
# 9          Soda  ...  Mid-range product      Least busy    Slowest days
# 10         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 11         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 12         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 13         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 14         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 15         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 16         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 17         Soda  ...  Mid-range product      Least busy    Slowest days
# 18         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 19         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 20         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 21         Soda  ...  Mid-range product      Least busy    Slowest days
# 22         Soda  ...  Mid-range product      Least busy    Slowest days
# 23         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 24         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 25         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 26         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 27         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 28         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 29         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 30         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 31         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 32         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 33         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 34         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 35         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 36         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 37         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 38         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 39         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 40         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 41         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 42         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 43         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 44         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 45         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 46         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 47         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 48         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 49         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 50         Soda  ...  Mid-range product      Least busy    Slowest days
# 51         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 52         Soda  ...  Mid-range product     Busiest day    Busiest days
# 53         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 54         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 55         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 56         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 57         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 58         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 59         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 60         Soda  ...  Mid-range product     Busiest day    Busiest days
# 61         Soda  ...  Mid-range product      Least busy    Slowest days
# 62         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 63         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 64         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 65         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 66         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 67         Soda  ...  Mid-range product     Busiest day    Busiest days
# 68         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 69         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 70         Soda  ...  Mid-range product      Least busy    Slowest days
# 71         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 72         Soda  ...  Mid-range product      Least busy    Slowest days
# 73         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 74         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 75         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 76         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 77         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 78         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 79         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 80         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 81         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 82         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 83         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 84         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 85         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 86         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 87         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 88         Soda  ...  Mid-range product  Regularly busy    Slowest days
# 89         Soda  ...  Mid-range product      Least busy    Slowest days
# 90         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 91         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 92         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 93         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 94         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 95         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 96         Soda  ...  Mid-range product  Regularly busy  Regularly busy
# 97         Soda  ...  Mid-range product      Least busy    Slowest days
# 98         Soda  ...  Mid-range product  Regularly busy    Busiest days
# 99         Soda  ...  Mid-range product  Regularly busy    Slowest days
#
#    busiest_period_of_day max_order      loyalty_flag  avg_price spending_flag  \
# 0         Average Orders        10      New customer   6.367535   Low spender
# 1         Average Orders        10      New customer   6.367535   Low spender
# 2            Most Orders        10      New customer   6.367535   Low spender
# 3         Average Orders        10      New customer   6.367535   Low spender
# 4            Most Orders        10      New customer   6.367535   Low spender
# 5         Average Orders        10      New customer   6.367535   Low spender
# 6            Most Orders        10      New customer   6.367535   Low spender
# 7            Most Orders        10      New customer   6.367535   Low spender
# 8            Most Orders        10      New customer   6.367535   Low spender
# 9         Average Orders        10      New customer   6.367535   Low spender
# 10           Most Orders        22  Regular customer   3.980306   Low spender
# 11           Most Orders        22  Regular customer   3.980306   Low spender
# 12           Most Orders        22  Regular customer   3.980306   Low spender
# 13           Most Orders        22  Regular customer   3.980306   Low spender
# 14           Most Orders        22  Regular customer   3.980306   Low spender
# 15           Most Orders         9      New customer   8.372018   Low spender
# 16           Most Orders         9      New customer   8.372018   Low spender
# 17        Average Orders         9      New customer   8.372018   Low spender
# 18           Most Orders        33  Regular customer   7.012538   Low spender
# 19        Average Orders        20  Regular customer   8.137767   Low spender
# 20           Most Orders        20  Regular customer   8.137767   Low spender
# 21           Most Orders        11  Regular customer   7.444980   Low spender
# 22           Most Orders        11  Regular customer   7.444980   Low spender
# 23           Most Orders        27  Regular customer   6.356293   Low spender
# 24           Most Orders        27  Regular customer   6.356293   Low spender
# 25           Most Orders        27  Regular customer   6.356293   Low spender
# 26           Most Orders        27  Regular customer   6.356293   Low spender
# 27        Average Orders        27  Regular customer   6.356293   Low spender
# 28           Most Orders        27  Regular customer   6.356293   Low spender
# 29           Most Orders        27  Regular customer   6.356293   Low spender
# 30           Most Orders        27  Regular customer   6.356293   Low spender
# 31           Most Orders        27  Regular customer   6.356293   Low spender
# 32           Most Orders        27  Regular customer   6.356293   Low spender
# 33           Most Orders        27  Regular customer   6.356293   Low spender
# 34           Most Orders        27  Regular customer   6.356293   Low spender
# 35        Average Orders        27  Regular customer   6.356293   Low spender
# 36           Most Orders        27  Regular customer   6.356293   Low spender
# 37           Most Orders        24  Regular customer   7.656539   Low spender
# 38           Most Orders        24  Regular customer   7.656539   Low spender
# 39           Most Orders        24  Regular customer   7.656539   Low spender
# 40           Most Orders        24  Regular customer   7.656539   Low spender
# 41           Most Orders        24  Regular customer   7.656539   Low spender
# 42           Most Orders        24  Regular customer   7.656539   Low spender
# 43           Most Orders        24  Regular customer   7.656539   Low spender
# 44           Most Orders        24  Regular customer   7.656539   Low spender
# 45           Most Orders        24  Regular customer   7.656539   Low spender
# 46           Most Orders        24  Regular customer   7.656539   Low spender
# 47           Most Orders        24  Regular customer   7.656539   Low spender
# 48           Most Orders        24  Regular customer   7.656539   Low spender
# 49           Most Orders        24  Regular customer   7.656539   Low spender
# 50           Most Orders        24  Regular customer   7.656539   Low spender
# 51           Most Orders        24  Regular customer   7.656539   Low spender
# 52           Most Orders        24  Regular customer   7.656539   Low spender
# 53           Most Orders        24  Regular customer   7.656539   Low spender
# 54           Most Orders        24  Regular customer   7.656539   Low spender
# 55           Most Orders        24  Regular customer   7.656539   Low spender
# 56           Most Orders         7      New customer   8.164363   Low spender
# 57        Average Orders         7      New customer   8.164363   Low spender
# 58           Most Orders        19  Regular customer   6.440706   Low spender
# 59           Most Orders        19  Regular customer   6.440706   Low spender
# 60           Most Orders        19  Regular customer   6.440706   Low spender
# 61           Most Orders        19  Regular customer   6.440706   Low spender
# 62           Most Orders        19  Regular customer   6.440706   Low spender
# 63           Most Orders        19  Regular customer   6.440706   Low spender
# 64           Most Orders        19  Regular customer   6.440706   Low spender
# 65           Most Orders        19  Regular customer   6.440706   Low spender
# 66           Most Orders        19  Regular customer   6.440706   Low spender
# 67           Most Orders        14  Regular customer   8.027891   Low spender
# 68           Most Orders        14  Regular customer   8.027891   Low spender
# 69           Most Orders        14  Regular customer   8.027891   Low spender
# 70           Most Orders        14  Regular customer   8.027891   Low spender
# 71           Most Orders        14  Regular customer   8.027891   Low spender
# 72           Most Orders        14  Regular customer   8.027891   Low spender
# 73        Average Orders        14  Regular customer   8.027891   Low spender
# 74        Average Orders         6      New customer   5.850430   Low spender
# 75           Most Orders         3      New customer   9.384766   Low spender
# 76        Average Orders         3      New customer   9.384766   Low spender
# 77           Most Orders         6      New customer   7.715210   Low spender
# 78           Most Orders        58    Loyal customer   7.149842   Low spender
# 79           Most Orders        58    Loyal customer   7.149842   Low spender
# 80           Most Orders        58    Loyal customer   7.149842   Low spender
# 81           Most Orders        58    Loyal customer   7.149842   Low spender
# 82           Most Orders        58    Loyal customer   7.149842   Low spender
# 83        Average Orders        58    Loyal customer   7.149842   Low spender
# 84           Most Orders        58    Loyal customer   7.149842   Low spender
# 85           Most Orders        58    Loyal customer   7.149842   Low spender
# 86           Most Orders        58    Loyal customer   7.149842   Low spender
# 87           Most Orders        58    Loyal customer   7.149842   Low spender
# 88           Most Orders        58    Loyal customer   7.149842   Low spender
# 89           Most Orders        58    Loyal customer   7.149842   Low spender
# 90           Most Orders        70    Loyal customer   6.862379   Low spender
# 91           Most Orders        70    Loyal customer   6.862379   Low spender
# 92        Average Orders        51    Loyal customer   7.285560   Low spender
# 93           Most Orders        51    Loyal customer   7.285560   Low spender
# 94           Most Orders         8      New customer   7.704577   Low spender
# 95           Most Orders         3      New customer  10.006287  High spender
# 96        Average Orders         3      New customer   8.496262   Low spender
# 97           Most Orders         8      New customer   7.396153   Low spender
# 98        Average Orders        22  Regular customer   7.387799   Low spender
# 99        Average Orders        22  Regular customer   7.387799   Low spender
#
#     median_days         frequency_flag
# 0          20.5  Non-frequent customer
# 1          20.5  Non-frequent customer
# 2          20.5  Non-frequent customer
# 3          20.5  Non-frequent customer
# 4          20.5  Non-frequent customer
# 5          20.5  Non-frequent customer
# 6          20.5  Non-frequent customer
# 7          20.5  Non-frequent customer
# 8          20.5  Non-frequent customer
# 9          20.5  Non-frequent customer
# 10         10.0      Frequent customer
# 11         10.0      Frequent customer
# 12         10.0      Frequent customer
# 13         10.0      Frequent customer
# 14         10.0      Frequent customer
# 15          6.0      Frequent customer
# 16          6.0      Frequent customer
# 17          6.0      Frequent customer
# 18          7.5      Frequent customer
# 19          6.0      Frequent customer
# 20          6.0      Frequent customer
# 21         10.0      Frequent customer
# 22         10.0      Frequent customer
# 23          8.0      Frequent customer
# 24          8.0      Frequent customer
# 25          8.0      Frequent customer
# 26          8.0      Frequent customer
# 27          8.0      Frequent customer
# 28          8.0      Frequent customer
# 29          8.0      Frequent customer
# 30          8.0      Frequent customer
# 31          8.0      Frequent customer
# 32          8.0      Frequent customer
# 33          8.0      Frequent customer
# 34          8.0      Frequent customer
# 35          8.0      Frequent customer
# 36          8.0      Frequent customer
# 37          7.0      Frequent customer
# 38          7.0      Frequent customer
# 39          7.0      Frequent customer
# 40          7.0      Frequent customer
# 41          7.0      Frequent customer
# 42          7.0      Frequent customer
# 43          7.0      Frequent customer
# 44          7.0      Frequent customer
# 45          7.0      Frequent customer
# 46          7.0      Frequent customer
# 47          7.0      Frequent customer
# 48          7.0      Frequent customer
# 49          7.0      Frequent customer
# 50          7.0      Frequent customer
# 51          7.0      Frequent customer
# 52          7.0      Frequent customer
# 53          7.0      Frequent customer
# 54          7.0      Frequent customer
# 55          7.0      Frequent customer
# 56         30.0  Non-frequent customer
# 57         30.0  Non-frequent customer
# 58         11.5       Regular customer
# 59         11.5       Regular customer
# 60         11.5       Regular customer
# 61         11.5       Regular customer
# 62         11.5       Regular customer
# 63         11.5       Regular customer
# 64         11.5       Regular customer
# 65         11.5       Regular customer
# 66         11.5       Regular customer
# 67         25.0  Non-frequent customer
# 68         25.0  Non-frequent customer
# 69         25.0  Non-frequent customer
# 70         25.0  Non-frequent customer
# 71         25.0  Non-frequent customer
# 72         25.0  Non-frequent customer
# 73         25.0  Non-frequent customer
# 74         26.0  Non-frequent customer
# 75         19.0       Regular customer
# 76         19.0       Regular customer
# 77         25.0  Non-frequent customer
# 78          4.0      Frequent customer
# 79          4.0      Frequent customer
# 80          4.0      Frequent customer
# 81          4.0      Frequent customer
# 82          4.0      Frequent customer
# 83          4.0      Frequent customer
# 84          4.0      Frequent customer
# 85          4.0      Frequent customer
# 86          4.0      Frequent customer
# 87          4.0      Frequent customer
# 88          4.0      Frequent customer
# 89          4.0      Frequent customer
# 90          5.0      Frequent customer
# 91          5.0      Frequent customer
# 92          7.0      Frequent customer
# 93          7.0      Frequent customer
# 94         30.0  Non-frequent customer
# 95          4.0      Frequent customer
# 96         16.5       Regular customer
# 97          8.0      Frequent customer
# 98          7.0      Frequent customer
# 99          7.0      Frequent customer
#
# [100 rows x 24 columns]

# %%
df_ords_prods_last_updated.loc[df_ords_prods_last_updated['prices'] >100, 'prices'] = np.nan

# %%
# Exporting data in pickle format since it's huge
df_ords_prods_last_updated.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'Orders_Products_Aggregated_4.8.pkl'))
